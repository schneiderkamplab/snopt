# %%
import sys
# !{sys.executable} -m pip install --upgrade matplotlib pandas pip
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# Requirement already satisfied: matplotlib in /Users/petersk/anaconda3/envs/alphadev/lib/python3.10/site-packages (3.8.2)
# Requirement already satisfied: pandas in /Users/petersk/anaconda3/envs/alphadev/lib/python3.10/site-packages (2.1.4)
# Requirement already satisfied: pip in /Users/petersk/anaconda3/envs/alphadev/lib/python3.10/site-packages (23.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/petersk/anaconda3/envs/alphadev/lib/python3.10/site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /Users/petersk/anaconda3/envs/alphadev/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/petersk/anaconda3/envs/alphadev/lib/python3.10/site-packages (from matplotlib) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/petersk/anaconda3/envs/alphadev/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in /Users/petersk/anaconda3/envs/alphadev/lib/python3.10/site-packages (from matplotlib) (1.25.1)
# Requirement already satisfied: packaging>=20.0 in /Users/petersk/anaconda3/envs/alphadev/lib/python3.10/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=8 in /Users/petersk/anaconda3/envs/alphadev/lib/python3.10/site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/petersk/anaconda3/envs/alphadev/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/petersk/anaconda3/envs/alphadev/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/petersk/anaconda3/envs/alphadev/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/petersk/anaconda3/envs/alphadev/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/petersk/anaconda3/envs/alphadev/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
df = pd.read_csv("paper.csv", delimiter=" ")

# %%
sr = df.to_dict(orient="records")
sr
# Out:
# [{'inputs': 2,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 4,
#   'prog_saved': 0,
#   'prog_regs': 3,
#   'cpu_time': 0.000739},
#  {'inputs': 2,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'z3',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 4,
#   'prog_saved': 0,
#   'prog_regs': 3,
#   'cpu_time': 0.000815},
#  {'inputs': 2,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 0,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 4,
#   'prog_saved': 0,
#   'prog_regs': 3,
#   'cpu_time': 0.001029},
#  {'inputs': 2,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 4,
#   'prog_saved': 0,
#   'prog_regs': 3,
#   'cpu_time': 0.001479},
#  {'inputs': 2,
#   'snt': 'jgamble_batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': False,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': True,
#   'reallocate': True,
#   'prog_len': 4,
#   'prog_saved': 0,
#   'prog_regs': 3,
#   'cpu_time': 0.019034},
#  {'inputs': 2,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 4,
#   'prog_saved': 0,
#   'prog_regs': 3,
#   'cpu_time': 0.015059},
#  {'inputs': 2,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'z3',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 4,
#   'prog_saved': 0,
#   'prog_regs': 3,
#   'cpu_time': 0.015847},
#  {'inputs': 2,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 0,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 4,
#   'prog_saved': 0,
#   'prog_regs': 3,
#   'cpu_time': 0.017081},
#  {'inputs': 2,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 4,
#   'prog_saved': 0,
#   'prog_regs': 3,
#   'cpu_time': 0.021712},
#  {'inputs': 3,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 12,
#   'prog_saved': 0,
#   'prog_regs': 4,
#   'cpu_time': 0.005046},
#  {'inputs': 3,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'z3',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 12,
#   'prog_saved': 0,
#   'prog_regs': 4,
#   'cpu_time': 0.023539},
#  {'inputs': 3,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 0,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 12,
#   'prog_saved': 0,
#   'prog_regs': 4,
#   'cpu_time': 0.00488},
#  {'inputs': 3,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 12,
#   'prog_saved': 0,
#   'prog_regs': 4,
#   'cpu_time': 0.004199},
#  {'inputs': 3,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 12,
#   'prog_saved': 0,
#   'prog_regs': 4,
#   'cpu_time': 0.013821},
#  {'inputs': 3,
#   'snt': 'jgamble_batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': False,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': True,
#   'reallocate': True,
#   'prog_len': 12,
#   'prog_saved': 0,
#   'prog_regs': 4,
#   'cpu_time': 0.111156},
#  {'inputs': 3,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 11,
#   'prog_saved': 1,
#   'prog_regs': 4,
#   'cpu_time': 0.020748},
#  {'inputs': 3,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'z3',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 11,
#   'prog_saved': 1,
#   'prog_regs': 4,
#   'cpu_time': 0.058047},
#  {'inputs': 3,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 0,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 11,
#   'prog_saved': 1,
#   'prog_regs': 4,
#   'cpu_time': 0.021294},
#  {'inputs': 3,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 11,
#   'prog_saved': 1,
#   'prog_regs': 4,
#   'cpu_time': 0.021338},
#  {'inputs': 3,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 11,
#   'prog_saved': 1,
#   'prog_regs': 4,
#   'cpu_time': 0.025084},
#  {'inputs': 4,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 20,
#   'prog_saved': 0,
#   'prog_regs': 5,
#   'cpu_time': 0.005282},
#  {'inputs': 4,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'z3',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 20,
#   'prog_saved': 0,
#   'prog_regs': 5,
#   'cpu_time': 0.028855},
#  {'inputs': 4,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 0,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 20,
#   'prog_saved': 0,
#   'prog_regs': 5,
#   'cpu_time': 0.005552},
#  {'inputs': 4,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 20,
#   'prog_saved': 0,
#   'prog_regs': 5,
#   'cpu_time': 0.004951},
#  {'inputs': 4,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 20,
#   'prog_saved': 0,
#   'prog_regs': 5,
#   'cpu_time': 0.006112},
#  {'inputs': 4,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 20,
#   'prog_saved': 0,
#   'prog_regs': 5,
#   'cpu_time': 0.006263},
#  {'inputs': 4,
#   'snt': 'jgamble_batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': False,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': True,
#   'reallocate': True,
#   'prog_len': 20,
#   'prog_saved': 0,
#   'prog_regs': 5,
#   'cpu_time': 0.250209},
#  {'inputs': 4,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 20,
#   'prog_saved': 0,
#   'prog_regs': 5,
#   'cpu_time': 0.026967},
#  {'inputs': 4,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'z3',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 20,
#   'prog_saved': 0,
#   'prog_regs': 5,
#   'cpu_time': 0.093158},
#  {'inputs': 4,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 0,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 20,
#   'prog_saved': 0,
#   'prog_regs': 5,
#   'cpu_time': 0.028361},
#  {'inputs': 4,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 20,
#   'prog_saved': 0,
#   'prog_regs': 5,
#   'cpu_time': 0.028989},
#  {'inputs': 4,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 20,
#   'prog_saved': 0,
#   'prog_regs': 5,
#   'cpu_time': 0.032368},
#  {'inputs': 4,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 20,
#   'prog_saved': 0,
#   'prog_regs': 5,
#   'cpu_time': 0.03397},
#  {'inputs': 5,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 35,
#   'prog_saved': 1,
#   'prog_regs': 6,
#   'cpu_time': 0.024384},
#  {'inputs': 5,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'z3',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 35,
#   'prog_saved': 1,
#   'prog_regs': 6,
#   'cpu_time': 0.154112},
#  {'inputs': 5,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 0,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 35,
#   'prog_saved': 1,
#   'prog_regs': 6,
#   'cpu_time': 0.029947},
#  {'inputs': 5,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 36,
#   'prog_saved': 0,
#   'prog_regs': 6,
#   'cpu_time': 0.01699},
#  {'inputs': 5,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 36,
#   'prog_saved': 0,
#   'prog_regs': 6,
#   'cpu_time': 0.017581},
#  {'inputs': 5,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 36,
#   'prog_saved': 0,
#   'prog_regs': 6,
#   'cpu_time': 0.017737},
#  {'inputs': 5,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 35,
#   'prog_saved': 1,
#   'prog_regs': 6,
#   'cpu_time': 0.025515},
#  {'inputs': 5,
#   'snt': 'jgamble_batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': False,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': True,
#   'reallocate': True,
#   'prog_len': 35,
#   'prog_saved': 1,
#   'prog_regs': 6,
#   'cpu_time': 0.983399},
#  {'inputs': 5,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 33,
#   'prog_saved': 3,
#   'prog_regs': 6,
#   'cpu_time': 0.054882},
#  {'inputs': 5,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'z3',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 33,
#   'prog_saved': 3,
#   'prog_regs': 6,
#   'cpu_time': 0.250481},
#  {'inputs': 5,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 0,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 33,
#   'prog_saved': 3,
#   'prog_regs': 6,
#   'cpu_time': 0.063916},
#  {'inputs': 5,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 34,
#   'prog_saved': 2,
#   'prog_regs': 6,
#   'cpu_time': 0.041083},
#  {'inputs': 5,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 34,
#   'prog_saved': 2,
#   'prog_regs': 6,
#   'cpu_time': 0.041206},
#  {'inputs': 5,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 34,
#   'prog_saved': 2,
#   'prog_regs': 6,
#   'cpu_time': 0.042632},
#  {'inputs': 5,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 33,
#   'prog_saved': 3,
#   'prog_regs': 6,
#   'cpu_time': 0.04929},
#  {'inputs': 6,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 47,
#   'prog_saved': 1,
#   'prog_regs': 7,
#   'cpu_time': 0.033164},
#  {'inputs': 6,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'z3',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 47,
#   'prog_saved': 1,
#   'prog_regs': 7,
#   'cpu_time': 0.203666},
#  {'inputs': 6,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 0,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 47,
#   'prog_saved': 1,
#   'prog_regs': 7,
#   'cpu_time': 0.039872},
#  {'inputs': 6,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 48,
#   'prog_saved': 0,
#   'prog_regs': 7,
#   'cpu_time': 0.021286},
#  {'inputs': 6,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 48,
#   'prog_saved': 0,
#   'prog_regs': 7,
#   'cpu_time': 0.022622},
#  {'inputs': 6,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 48,
#   'prog_saved': 0,
#   'prog_regs': 7,
#   'cpu_time': 0.024785},
#  {'inputs': 6,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 47,
#   'prog_saved': 1,
#   'prog_regs': 7,
#   'cpu_time': 0.034349},
#  {'inputs': 6,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 3,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 47,
#   'prog_saved': 1,
#   'prog_regs': 7,
#   'cpu_time': 0.042985},
#  {'inputs': 6,
#   'snt': 'jgamble_batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': False,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': True,
#   'reallocate': True,
#   'prog_len': 47,
#   'prog_saved': 1,
#   'prog_regs': 7,
#   'cpu_time': 1.823241},
#  {'inputs': 6,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 45,
#   'prog_saved': 3,
#   'prog_regs': 8,
#   'cpu_time': 0.066914},
#  {'inputs': 6,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'z3',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 45,
#   'prog_saved': 3,
#   'prog_regs': 8,
#   'cpu_time': 0.297354},
#  {'inputs': 6,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 0,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 45,
#   'prog_saved': 3,
#   'prog_regs': 8,
#   'cpu_time': 0.077102},
#  {'inputs': 6,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 46,
#   'prog_saved': 2,
#   'prog_regs': 8,
#   'cpu_time': 0.048004},
#  {'inputs': 6,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 46,
#   'prog_saved': 2,
#   'prog_regs': 8,
#   'cpu_time': 0.049012},
#  {'inputs': 6,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 46,
#   'prog_saved': 2,
#   'prog_regs': 8,
#   'cpu_time': 0.053413},
#  {'inputs': 6,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 46,
#   'prog_saved': 2,
#   'prog_regs': 8,
#   'cpu_time': 0.066993},
#  {'inputs': 6,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 3,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 45,
#   'prog_saved': 3,
#   'prog_regs': 8,
#   'cpu_time': 0.082638},
#  {'inputs': 7,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 63,
#   'prog_saved': 1,
#   'prog_regs': 9,
#   'cpu_time': 0.054537},
#  {'inputs': 7,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'z3',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 63,
#   'prog_saved': 1,
#   'prog_regs': 9,
#   'cpu_time': 0.282554},
#  {'inputs': 7,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 0,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 63,
#   'prog_saved': 1,
#   'prog_regs': 9,
#   'cpu_time': 0.09197},
#  {'inputs': 7,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 64,
#   'prog_saved': 0,
#   'prog_regs': 8,
#   'cpu_time': 0.028931},
#  {'inputs': 7,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 64,
#   'prog_saved': 0,
#   'prog_regs': 8,
#   'cpu_time': 0.029641},
#  {'inputs': 7,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 64,
#   'prog_saved': 0,
#   'prog_regs': 8,
#   'cpu_time': 0.030252},
#  {'inputs': 7,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 63,
#   'prog_saved': 1,
#   'prog_regs': 9,
#   'cpu_time': 0.04656},
#  {'inputs': 7,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 3,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 63,
#   'prog_saved': 1,
#   'prog_regs': 9,
#   'cpu_time': 0.062399},
#  {'inputs': 7,
#   'snt': 'jgamble_batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': False,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': True,
#   'reallocate': True,
#   'prog_len': 63,
#   'prog_saved': 1,
#   'prog_regs': 9,
#   'cpu_time': 3.798125},
#  {'inputs': 7,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 60,
#   'prog_saved': 4,
#   'prog_regs': 9,
#   'cpu_time': 0.111965},
#  {'inputs': 7,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'z3',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 60,
#   'prog_saved': 4,
#   'prog_regs': 9,
#   'cpu_time': 0.508122},
#  {'inputs': 7,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 0,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 60,
#   'prog_saved': 4,
#   'prog_regs': 9,
#   'cpu_time': 0.132513},
#  {'inputs': 7,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 63,
#   'prog_saved': 1,
#   'prog_regs': 9,
#   'cpu_time': 0.066528},
#  {'inputs': 7,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 63,
#   'prog_saved': 1,
#   'prog_regs': 9,
#   'cpu_time': 0.07322},
#  {'inputs': 7,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 63,
#   'prog_saved': 1,
#   'prog_regs': 9,
#   'cpu_time': 0.081154},
#  {'inputs': 7,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 61,
#   'prog_saved': 3,
#   'prog_regs': 9,
#   'cpu_time': 0.110464},
#  {'inputs': 7,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 3,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 60,
#   'prog_saved': 4,
#   'prog_regs': 9,
#   'cpu_time': 0.108558},
#  {'inputs': 8,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 75,
#   'prog_saved': 1,
#   'prog_regs': 10,
#   'cpu_time': 0.088367},
#  {'inputs': 8,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'z3',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 75,
#   'prog_saved': 1,
#   'prog_regs': 10,
#   'cpu_time': 0.407097},
#  {'inputs': 8,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 0,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 75,
#   'prog_saved': 1,
#   'prog_regs': 10,
#   'cpu_time': 0.105596},
#  {'inputs': 8,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 76,
#   'prog_saved': 0,
#   'prog_regs': 9,
#   'cpu_time': 0.032503},
#  {'inputs': 8,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 76,
#   'prog_saved': 0,
#   'prog_regs': 9,
#   'cpu_time': 0.035664},
#  {'inputs': 8,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 76,
#   'prog_saved': 0,
#   'prog_regs': 9,
#   'cpu_time': 0.038319},
#  {'inputs': 8,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 75,
#   'prog_saved': 1,
#   'prog_regs': 10,
#   'cpu_time': 0.046548},
#  {'inputs': 8,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 75,
#   'prog_saved': 1,
#   'prog_regs': 10,
#   'cpu_time': 0.052876},
#  {'inputs': 8,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 4,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 75,
#   'prog_saved': 1,
#   'prog_regs': 10,
#   'cpu_time': 0.104391},
#  {'inputs': 8,
#   'snt': 'jgamble_batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': False,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': True,
#   'reallocate': True,
#   'prog_len': 75,
#   'prog_saved': 1,
#   'prog_regs': 10,
#   'cpu_time': 5.261965},
#  {'inputs': 8,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 75,
#   'prog_saved': 1,
#   'prog_regs': 10,
#   'cpu_time': 0.144905},
#  {'inputs': 8,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'z3',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 75,
#   'prog_saved': 1,
#   'prog_regs': 10,
#   'cpu_time': 0.603036},
#  {'inputs': 8,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 0,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 75,
#   'prog_saved': 1,
#   'prog_regs': 10,
#   'cpu_time': 0.183204},
#  {'inputs': 8,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 76,
#   'prog_saved': 0,
#   'prog_regs': 9,
#   'cpu_time': 0.071127},
#  {'inputs': 8,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 76,
#   'prog_saved': 0,
#   'prog_regs': 9,
#   'cpu_time': 0.078544},
#  {'inputs': 8,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 76,
#   'prog_saved': 0,
#   'prog_regs': 9,
#   'cpu_time': 0.081844},
#  {'inputs': 8,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 75,
#   'prog_saved': 1,
#   'prog_regs': 10,
#   'cpu_time': 0.1016},
#  {'inputs': 8,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 75,
#   'prog_saved': 1,
#   'prog_regs': 10,
#   'cpu_time': 0.108028},
#  {'inputs': 8,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 4,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 75,
#   'prog_saved': 1,
#   'prog_regs': 10,
#   'cpu_time': 0.184991},
#  {'inputs': 9,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 101,
#   'prog_saved': 3,
#   'prog_regs': 11,
#   'cpu_time': 0.167898},
#  {'inputs': 9,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'z3',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 101,
#   'prog_saved': 3,
#   'prog_regs': 11,
#   'cpu_time': 0.756975},
#  {'inputs': 9,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 0,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 101,
#   'prog_saved': 3,
#   'prog_regs': 11,
#   'cpu_time': 0.226293},
#  {'inputs': 9,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 104,
#   'prog_saved': 0,
#   'prog_regs': 10,
#   'cpu_time': 0.070173},
#  {'inputs': 9,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 104,
#   'prog_saved': 0,
#   'prog_regs': 10,
#   'cpu_time': 0.072133},
#  {'inputs': 9,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 104,
#   'prog_saved': 0,
#   'prog_regs': 10,
#   'cpu_time': 0.07907},
#  {'inputs': 9,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 102,
#   'prog_saved': 2,
#   'prog_regs': 11,
#   'cpu_time': 0.103668},
#  {'inputs': 9,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 3,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 101,
#   'prog_saved': 3,
#   'prog_regs': 11,
#   'cpu_time': 0.197397},
#  {'inputs': 9,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 4,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 101,
#   'prog_saved': 3,
#   'prog_regs': 11,
#   'cpu_time': 0.19367},
#  {'inputs': 9,
#   'snt': 'jgamble_batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': False,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': True,
#   'reallocate': True,
#   'prog_len': 101,
#   'prog_saved': 3,
#   'prog_regs': 11,
#   'cpu_time': 13.396205},
#  {'inputs': 9,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 99,
#   'prog_saved': 1,
#   'prog_regs': 11,
#   'cpu_time': 0.222361},
#  {'inputs': 9,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'z3',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 99,
#   'prog_saved': 1,
#   'prog_regs': 11,
#   'cpu_time': 0.848849},
#  {'inputs': 9,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 0,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 99,
#   'prog_saved': 1,
#   'prog_regs': 11,
#   'cpu_time': 0.284993},
#  {'inputs': 9,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 100,
#   'prog_saved': 0,
#   'prog_regs': 10,
#   'cpu_time': 0.092984},
#  {'inputs': 9,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 100,
#   'prog_saved': 0,
#   'prog_regs': 10,
#   'cpu_time': 0.095631},
#  {'inputs': 9,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 100,
#   'prog_saved': 0,
#   'prog_regs': 10,
#   'cpu_time': 0.097284},
#  {'inputs': 9,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 100,
#   'prog_saved': 0,
#   'prog_regs': 10,
#   'cpu_time': 0.121096},
#  {'inputs': 9,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 3,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 100,
#   'prog_saved': 0,
#   'prog_regs': 10,
#   'cpu_time': 0.180513},
#  {'inputs': 9,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 4,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 99,
#   'prog_saved': 1,
#   'prog_regs': 11,
#   'cpu_time': 0.194535},
#  {'inputs': 10,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 120,
#   'prog_saved': 4,
#   'prog_regs': 13,
#   'cpu_time': 0.253619},
#  {'inputs': 10,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'z3',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 120,
#   'prog_saved': 4,
#   'prog_regs': 13,
#   'cpu_time': 1.054356},
#  {'inputs': 10,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 0,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 120,
#   'prog_saved': 4,
#   'prog_regs': 13,
#   'cpu_time': 0.335656},
#  {'inputs': 10,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 124,
#   'prog_saved': 0,
#   'prog_regs': 11,
#   'cpu_time': 0.096361},
#  {'inputs': 10,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 124,
#   'prog_saved': 0,
#   'prog_regs': 11,
#   'cpu_time': 0.100981},
#  {'inputs': 10,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 121,
#   'prog_saved': 3,
#   'prog_regs': 13,
#   'cpu_time': 0.14751},
#  {'inputs': 10,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 121,
#   'prog_saved': 3,
#   'prog_regs': 13,
#   'cpu_time': 0.156828},
#  {'inputs': 10,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 3,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 120,
#   'prog_saved': 4,
#   'prog_regs': 13,
#   'cpu_time': 0.221515},
#  {'inputs': 10,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 5,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 120,
#   'prog_saved': 4,
#   'prog_regs': 13,
#   'cpu_time': 0.298673},
#  {'inputs': 10,
#   'snt': 'jgamble_batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': False,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': True,
#   'reallocate': True,
#   'prog_len': 120,
#   'prog_saved': 4,
#   'prog_regs': 13,
#   'cpu_time': 20.311519},
#  {'inputs': 10,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 116,
#   'prog_saved': 0,
#   'prog_regs': 11,
#   'cpu_time': 0.166118},
#  {'inputs': 10,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'z3',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 116,
#   'prog_saved': 0,
#   'prog_regs': 11,
#   'cpu_time': 0.62529},
#  {'inputs': 10,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 0,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 116,
#   'prog_saved': 0,
#   'prog_regs': 11,
#   'cpu_time': 0.257641},
#  {'inputs': 10,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 116,
#   'prog_saved': 0,
#   'prog_regs': 11,
#   'cpu_time': 0.097343},
#  {'inputs': 10,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 116,
#   'prog_saved': 0,
#   'prog_regs': 11,
#   'cpu_time': 0.102307},
#  {'inputs': 10,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 116,
#   'prog_saved': 0,
#   'prog_regs': 11,
#   'cpu_time': 0.1283},
#  {'inputs': 10,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 116,
#   'prog_saved': 0,
#   'prog_regs': 11,
#   'cpu_time': 0.132526},
#  {'inputs': 10,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 3,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 116,
#   'prog_saved': 0,
#   'prog_regs': 11,
#   'cpu_time': 0.15131},
#  {'inputs': 10,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 5,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 116,
#   'prog_saved': 0,
#   'prog_regs': 11,
#   'cpu_time': 0.195942},
#  {'inputs': 11,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 143,
#   'prog_saved': 5,
#   'prog_regs': 13,
#   'cpu_time': 0.317307},
#  {'inputs': 11,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'z3',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 143,
#   'prog_saved': 5,
#   'prog_regs': 13,
#   'cpu_time': 1.42201},
#  {'inputs': 11,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 0,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 143,
#   'prog_saved': 5,
#   'prog_regs': 13,
#   'cpu_time': 0.456347},
#  {'inputs': 11,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 148,
#   'prog_saved': 0,
#   'prog_regs': 12,
#   'cpu_time': 0.12268},
#  {'inputs': 11,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 148,
#   'prog_saved': 0,
#   'prog_regs': 12,
#   'cpu_time': 0.130311},
#  {'inputs': 11,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 145,
#   'prog_saved': 3,
#   'prog_regs': 13,
#   'cpu_time': 0.210542},
#  {'inputs': 11,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 145,
#   'prog_saved': 3,
#   'prog_regs': 13,
#   'cpu_time': 0.263934},
#  {'inputs': 11,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 3,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 143,
#   'prog_saved': 5,
#   'prog_regs': 13,
#   'cpu_time': 0.278123},
#  {'inputs': 11,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 5,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 143,
#   'prog_saved': 5,
#   'prog_regs': 13,
#   'cpu_time': 0.376263},
#  {'inputs': 11,
#   'snt': 'jgamble_batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': False,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': True,
#   'reallocate': True,
#   'prog_len': 143,
#   'prog_saved': 5,
#   'prog_regs': 13,
#   'cpu_time': 32.580139},
#  {'inputs': 11,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 140,
#   'prog_saved': 0,
#   'prog_regs': 12,
#   'cpu_time': 0.339062},
#  {'inputs': 11,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'z3',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 140,
#   'prog_saved': 0,
#   'prog_regs': 12,
#   'cpu_time': 1.35675},
#  {'inputs': 11,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 0,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 140,
#   'prog_saved': 0,
#   'prog_regs': 12,
#   'cpu_time': 0.481005},
#  {'inputs': 11,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 140,
#   'prog_saved': 0,
#   'prog_regs': 12,
#   'cpu_time': 0.141594},
#  {'inputs': 11,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 140,
#   'prog_saved': 0,
#   'prog_regs': 12,
#   'cpu_time': 0.152706},
#  {'inputs': 11,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 140,
#   'prog_saved': 0,
#   'prog_regs': 12,
#   'cpu_time': 0.185382},
#  {'inputs': 11,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 140,
#   'prog_saved': 0,
#   'prog_regs': 12,
#   'cpu_time': 0.225866},
#  {'inputs': 11,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 3,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 140,
#   'prog_saved': 0,
#   'prog_regs': 12,
#   'cpu_time': 0.275562},
#  {'inputs': 11,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 5,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 140,
#   'prog_saved': 0,
#   'prog_regs': 12,
#   'cpu_time': 0.392393},
#  {'inputs': 12,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 159,
#   'prog_saved': 5,
#   'prog_regs': 15,
#   'cpu_time': 0.386373},
#  {'inputs': 12,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'z3',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 159,
#   'prog_saved': 5,
#   'prog_regs': 15,
#   'cpu_time': 1.697495},
#  {'inputs': 12,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 0,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 159,
#   'prog_saved': 5,
#   'prog_regs': 15,
#   'cpu_time': 0.577791},
#  {'inputs': 12,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 164,
#   'prog_saved': 0,
#   'prog_regs': 13,
#   'cpu_time': 0.141533},
#  {'inputs': 12,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 161,
#   'prog_saved': 3,
#   'prog_regs': 15,
#   'cpu_time': 0.244362},
#  {'inputs': 12,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 161,
#   'prog_saved': 3,
#   'prog_regs': 15,
#   'cpu_time': 0.252834},
#  {'inputs': 12,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 3,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 160,
#   'prog_saved': 4,
#   'prog_regs': 15,
#   'cpu_time': 0.2961},
#  {'inputs': 12,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 4,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 159,
#   'prog_saved': 5,
#   'prog_regs': 15,
#   'cpu_time': 0.366552},
#  {'inputs': 12,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 6,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 159,
#   'prog_saved': 5,
#   'prog_regs': 15,
#   'cpu_time': 0.526721},
#  {'inputs': 12,
#   'snt': 'jgamble_batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': False,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': True,
#   'reallocate': True,
#   'prog_len': 159,
#   'prog_saved': 5,
#   'prog_regs': 15,
#   'cpu_time': 40.521127},
#  {'inputs': 12,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 156,
#   'prog_saved': 0,
#   'prog_regs': 13,
#   'cpu_time': 0.412157},
#  {'inputs': 12,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'z3',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 156,
#   'prog_saved': 0,
#   'prog_regs': 13,
#   'cpu_time': 1.510989},
#  {'inputs': 12,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 0,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 156,
#   'prog_saved': 0,
#   'prog_regs': 13,
#   'cpu_time': 0.610177},
#  {'inputs': 12,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 156,
#   'prog_saved': 0,
#   'prog_regs': 13,
#   'cpu_time': 0.172143},
#  {'inputs': 12,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 156,
#   'prog_saved': 0,
#   'prog_regs': 13,
#   'cpu_time': 0.242545},
#  {'inputs': 12,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 156,
#   'prog_saved': 0,
#   'prog_regs': 13,
#   'cpu_time': 0.248217},
#  {'inputs': 12,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 3,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 156,
#   'prog_saved': 0,
#   'prog_regs': 13,
#   'cpu_time': 0.3418},
#  {'inputs': 12,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 4,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 156,
#   'prog_saved': 0,
#   'prog_regs': 13,
#   'cpu_time': 0.439023},
#  {'inputs': 12,
#   'snt': 'jgamble_best',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 6,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 156,
#   'prog_saved': 0,
#   'prog_regs': 13,
#   'cpu_time': 0.524563},
# ...
#  {'inputs': 79,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3004,
#   'prog_saved': 96,
#   'prog_regs': 95,
#   'cpu_time': 685.188221},
#  {'inputs': 79,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 13,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3004,
#   'prog_saved': 96,
#   'prog_regs': 95,
#   'cpu_time': 668.610659},
#  {'inputs': 79,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 15,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3004,
#   'prog_saved': 96,
#   'prog_regs': 95,
#   'cpu_time': 918.469635},
#  {'inputs': 79,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 19,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3004,
#   'prog_saved': 96,
#   'prog_regs': 95,
#   'cpu_time': 799.128093},
#  {'inputs': 79,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3070,
#   'prog_saved': 30,
#   'prog_regs': 95,
#   'cpu_time': 460.983608},
#  {'inputs': 79,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 26,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3004,
#   'prog_saved': 96,
#   'prog_regs': 95,
#   'cpu_time': 813.145438},
#  {'inputs': 79,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 39,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3004,
#   'prog_saved': 96,
#   'prog_regs': 95,
#   'cpu_time': 748.567338},
#  {'inputs': 79,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 4,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3051,
#   'prog_saved': 49,
#   'prog_regs': 95,
#   'cpu_time': 512.046861},
#  {'inputs': 79,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 9,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3014,
#   'prog_saved': 86,
#   'prog_regs': 95,
#   'cpu_time': 691.923338},
#  {'inputs': 80,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3035,
#   'prog_saved': 97,
#   'prog_regs': 97,
#   'cpu_time': 692.303958},
#  {'inputs': 80,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 10,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3039,
#   'prog_saved': 93,
#   'prog_regs': 97,
#   'cpu_time': 611.225388},
#  {'inputs': 80,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 13,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3035,
#   'prog_saved': 97,
#   'prog_regs': 97,
#   'cpu_time': 804.475111},
#  {'inputs': 80,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 16,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3035,
#   'prog_saved': 97,
#   'prog_regs': 97,
#   'cpu_time': 821.931814},
#  {'inputs': 80,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3101,
#   'prog_saved': 31,
#   'prog_regs': 97,
#   'cpu_time': 512.260676},
#  {'inputs': 80,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 20,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3035,
#   'prog_saved': 97,
#   'prog_regs': 97,
#   'cpu_time': 823.443863},
#  {'inputs': 80,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 26,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3035,
#   'prog_saved': 97,
#   'prog_regs': 97,
#   'cpu_time': 775.410823},
#  {'inputs': 80,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 40,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3035,
#   'prog_saved': 97,
#   'prog_regs': 97,
#   'cpu_time': 740.035918},
#  {'inputs': 80,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 5,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3072,
#   'prog_saved': 60,
#   'prog_regs': 97,
#   'cpu_time': 554.971934},
#  {'inputs': 81,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3115,
#   'prog_saved': 101,
#   'prog_regs': 97,
#   'cpu_time': 742.980937},
#  {'inputs': 81,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 10,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3121,
#   'prog_saved': 95,
#   'prog_regs': 97,
#   'cpu_time': 642.84394},
#  {'inputs': 81,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 13,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3115,
#   'prog_saved': 101,
#   'prog_regs': 97,
#   'cpu_time': 1079.823523},
#  {'inputs': 81,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 16,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3115,
#   'prog_saved': 101,
#   'prog_regs': 97,
#   'cpu_time': 864.906449},
#  {'inputs': 81,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3185,
#   'prog_saved': 31,
#   'prog_regs': 97,
#   'cpu_time': 530.436566},
#  {'inputs': 81,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 20,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3115,
#   'prog_saved': 101,
#   'prog_regs': 97,
#   'cpu_time': 834.37668},
#  {'inputs': 81,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 27,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3115,
#   'prog_saved': 101,
#   'prog_regs': 97,
#   'cpu_time': 857.500671},
#  {'inputs': 81,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 40,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3115,
#   'prog_saved': 101,
#   'prog_regs': 97,
#   'cpu_time': 836.683314},
#  {'inputs': 81,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 5,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3155,
#   'prog_saved': 61,
#   'prog_regs': 97,
#   'cpu_time': 627.161346},
#  {'inputs': 82,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3176,
#   'prog_saved': 104,
#   'prog_regs': 98,
#   'cpu_time': 806.712927},
#  {'inputs': 82,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 10,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3181,
#   'prog_saved': 99,
#   'prog_regs': 98,
#   'cpu_time': 837.364386},
#  {'inputs': 82,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 13,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3176,
#   'prog_saved': 104,
#   'prog_regs': 98,
#   'cpu_time': 897.819507},
#  {'inputs': 82,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 16,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3176,
#   'prog_saved': 104,
#   'prog_regs': 98,
#   'cpu_time': 1060.356473},
#  {'inputs': 82,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3249,
#   'prog_saved': 31,
#   'prog_regs': 98,
#   'cpu_time': 632.539444},
#  {'inputs': 82,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 20,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3176,
#   'prog_saved': 104,
#   'prog_regs': 98,
#   'cpu_time': 901.20239},
#  {'inputs': 82,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 27,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3176,
#   'prog_saved': 104,
#   'prog_regs': 98,
#   'cpu_time': 873.803194},
#  {'inputs': 82,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 41,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3176,
#   'prog_saved': 104,
#   'prog_regs': 98,
#   'cpu_time': 879.339317},
#  {'inputs': 82,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 5,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3218,
#   'prog_saved': 62,
#   'prog_regs': 98,
#   'cpu_time': 669.40676},
#  {'inputs': 83,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3241,
#   'prog_saved': 107,
#   'prog_regs': 99,
#   'cpu_time': 847.218092},
#  {'inputs': 83,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 10,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3246,
#   'prog_saved': 102,
#   'prog_regs': 99,
#   'cpu_time': 1076.395987},
#  {'inputs': 83,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 13,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3241,
#   'prog_saved': 107,
#   'prog_regs': 99,
#   'cpu_time': 835.494477},
#  {'inputs': 83,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 16,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3241,
#   'prog_saved': 107,
#   'prog_regs': 99,
#   'cpu_time': 1009.65953},
#  {'inputs': 83,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3317,
#   'prog_saved': 31,
#   'prog_regs': 99,
#   'cpu_time': 591.862452},
#  {'inputs': 83,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 20,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3241,
#   'prog_saved': 107,
#   'prog_regs': 99,
#   'cpu_time': 937.885427},
#  {'inputs': 83,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 27,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3241,
#   'prog_saved': 107,
#   'prog_regs': 99,
#   'cpu_time': 1106.471059},
#  {'inputs': 83,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 41,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3241,
#   'prog_saved': 107,
#   'prog_regs': 99,
#   'cpu_time': 964.451545},
#  {'inputs': 83,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 5,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3285,
#   'prog_saved': 63,
#   'prog_regs': 99,
#   'cpu_time': 740.145931},
#  {'inputs': 84,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3287,
#   'prog_saved': 109,
#   'prog_regs': 100,
#   'cpu_time': 810.17728},
#  {'inputs': 84,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 10,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3292,
#   'prog_saved': 104,
#   'prog_regs': 100,
#   'cpu_time': 832.477053},
#  {'inputs': 84,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 14,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3287,
#   'prog_saved': 109,
#   'prog_regs': 100,
#   'cpu_time': 1240.218302},
#  {'inputs': 84,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 16,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3287,
#   'prog_saved': 109,
#   'prog_regs': 100,
#   'cpu_time': 1028.389731},
#  {'inputs': 84,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 2,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3365,
#   'prog_saved': 31,
#   'prog_regs': 100,
#   'cpu_time': 652.992914},
#  {'inputs': 84,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 21,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3287,
#   'prog_saved': 109,
#   'prog_regs': 100,
#   'cpu_time': 983.571851},
#  {'inputs': 84,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 28,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3287,
#   'prog_saved': 109,
#   'prog_regs': 100,
#   'cpu_time': 1056.989062},
#  {'inputs': 84,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 42,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3287,
#   'prog_saved': 109,
#   'prog_regs': 100,
#   'cpu_time': 923.3397},
#  {'inputs': 84,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 5,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3332,
#   'prog_saved': 64,
#   'prog_regs': 100,
#   'cpu_time': 712.43505},
#  {'inputs': 85,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': -1,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3356,
#   'prog_saved': 112,
#   'prog_regs': 101,
#   'cpu_time': 886.70003},
#  {'inputs': 85,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 10,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3362,
#   'prog_saved': 106,
#   'prog_regs': 101,
#   'cpu_time': 865.060696},
#  {'inputs': 85,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 14,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3356,
#   'prog_saved': 112,
#   'prog_regs': 101,
#   'cpu_time': 927.411106},
#  {'inputs': 85,
#   'snt': 'batcher',
#   'do_max': False,
#   'try_min': True,
#   'try_max': False,
#   'prune': True,
#   'slice': 17,
#   'backend': 'sat',
#   'fallback': False,
#   'reallocate': True,
#   'prog_len': 3356,
#   'prog_saved': 112,
#   'prog_regs': 101,
#   'cpu_time': 1145.952929},
#  ...]

# %%
r1 = [{"inputs": r["inputs"], "standard": r["prog_len"]+r["prog_saved"], "optimized": r["prog_len"]} for r in sr if r["snt"] == "batcher" and r["slice"] == -1 and r["backend"] == "sat" and r["prune"] and r["inputs"] <= 128]
df1 = pd.DataFrame(r1)
df1
# Out:
#      inputs  standard  optimized
# 0         2         4          4
# 1         3        12         12
# 2         4        20         20
# 3         5        36         35
# 4         6        48         47
# ..      ...       ...        ...
# 122     124      5700       5571
# 123     125      5764       5635
# 124     126      5808       5679
# 125     127      5856       5727
# 126     128      5884       5755
#
# [127 rows x 3 columns]

# %%
plt.plot(df1["inputs"], df1["standard"])
plt.plot(df1["inputs"], df1["optimized"])

# %%
plt.plot(df1["inputs"][-16:], df1["standard"][-16:])
plt.plot(df1["inputs"][-16:], df1["optimized"][-16:])

# %%
r2 = [{"inputs": r["inputs"], "standard": r["inputs"]+1, "optimized": r["prog_regs"]} for r in sr if r["snt"] == "batcher" and r["slice"] == -1 and r["backend"] == "sat" and r["prune"] and r["inputs"] <= 128]
df2 = pd.DataFrame(r2)
df2
# Out:
#      inputs  standard  optimized
# 0         2         3          3
# 1         3         4          4
# 2         4         5          5
# 3         5         6          6
# 4         6         7          7
# ..      ...       ...        ...
# 122     124       125        141
# 123     125       126        142
# 124     126       127        143
# 125     127       128        144
# 126     128       129        145
#
# [127 rows x 3 columns]

# %%
plt.scatter(df2["inputs"], df2["standard"], marker="x")
plt.scatter(df2["inputs"], df2["optimized"], marker="x")
plt.savefig("figure_registers.pdf", format="pdf", bbox_inches="tight")

# %%
r3_z3 = [r["cpu_time"] for r in sr if r["snt"] == "batcher" and r["slice"] == -1 and r["backend"] == "z3" and r["prune"] and r["inputs"] <= 64]
r3_sat = [r["cpu_time"] for r in sr if r["snt"] == "batcher" and r["slice"] == -1 and r["backend"] == "sat" and r["prune"] and r["inputs"] <= 64]

# %%
plt.scatter(r3_sat, r3_z3, marker="x")
plt.plot([0,3600], [0,3600], ls="--", color="orange")
plt.plot([0,3600], [0,36000], ls="--", color="orange")
plt.plot([0,3600], [0,360], ls="--", color="orange")
plt.xscale("log")
plt.yscale("log")
plt.savefig("figure_sat_vs_z3.pdf", format="pdf", bbox_inches="tight")

# %%
r3_noslice = [r["cpu_time"] for r in sr if r["snt"] == "batcher" and r["slice"] == 0 and r["backend"] == "sat" and r["prune"] and r["inputs"] <= 64]
r3_slice = [r["cpu_time"] for r in sr if r["snt"] == "batcher" and r["slice"] == -1 and r["backend"] == "sat" and r["prune"] and r["inputs"] <= 64]

# %%
plt.scatter(r3_slice, r3_noslice, marker="x")
plt.plot([0,250], [0,250], ls="--", color="orange")
#plt.xscale("log")
#plt.yscale("log")
plt.savefig("figure_slicing.pdf", format="pdf", bbox_inches="tight")

# %%
inputs = [2, 3, 4, 5, 6, 7, 8]
comps = [1, 3, 5, 9, 12, 16, 19]
naive_length = [2*n+4*m for n, m in zip(inputs, comps)]
naive_saved = [0 for n in inputs]
alphadev_length = [8, 17, 28, 42, 57, 76, 91] 
alphadev_saved = [n-m for n, m in zip(naive_length, alphadev_length)]
systematized_length = [8, 17, 28, 43, 57, 74, 91] 
systematized_saved = [n-m for n, m in zip(naive_length, systematized_length)]
df4 = pd.DataFrame({
    "inputs": inputs,
    "comps": comps,
    "naive_length": naive_length,
    "alphadev_length": alphadev_length,
    "systematized_length": systematized_length,
    "naive_saved": naive_saved,
    "alphadev_saved": alphadev_saved,
    "systematized_saved": systematized_saved,
})
df4
# Out:
#    inputs  comps  naive_length  alphadev_length  systematized_length  \
# 0       2      1             8                8                    8
# 1       3      3            18               17                   17
# 2       4      5            28               28                   28
# 3       5      9            46               42                   43
# 4       6     12            60               57                   57
# 5       7     16            78               76                   74
# 6       8     19            92               91                   91
#
#    naive_saved  alphadev_saved  systematized_saved
# 0            0               0                   0
# 1            0               1                   1
# 2            0               0                   0
# 3            0               4                   3
# 4            0               3                   3
# 5            0               2                   4
# 6            0               1                   1

# %%
plt.scatter(inputs, alphadev_length, marker="x")
plt.scatter(inputs, systematized_length, marker="x")
plt.scatter(inputs, naive_length, marker="x", color="red")

# %%
plt.scatter(inputs, alphadev_saved, marker="x")
plt.scatter(inputs, systematized_saved, marker="x")

# %%
r5 = [{"inputs": r["inputs"], "saved": r["prog_saved"]} for r in sr if r["snt"] == "batcher" and r["slice"] == -1 and r["backend"] == "sat" and r["prune"] and r["inputs"] <= 128]
df5 = pd.DataFrame(r5)
df5
# Out:
#      inputs  saved
# 0         2      0
# 1         3      0
# 2         4      0
# 3         5      1
# 4         6      1
# ..      ...    ...
# 122     124    129
# 123     125    129
# 124     126    129
# 125     127    129
# 126     128    129
#
# [127 rows x 2 columns]

# %%
plt.plot(df5["inputs"], df5["saved"], marker="x")
plt.savefig("figure_saved.pdf", format="pdf", bbox_inches="tight")
